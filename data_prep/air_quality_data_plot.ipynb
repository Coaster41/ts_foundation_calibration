# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_air = pd.read_csv('../data/air+quality/AirQuality.csv', decimal=',', na_values=-200)
df_air
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1       1314.0       NaN      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0       NaN      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0       NaN      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0       NaN       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0       NaN      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
custom_format = '%d/%m/%Y%H.%M.%S'
df_air.insert(0,'ds', pd.to_datetime(df_air['Date'] + df_air["Time"], format=custom_format))
df_air
# Out:
#                       ds        Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  \
# 0    2004-03-10 18:00:00  10/03/2004  18.00.00     2.6       1360.0     150.0
# 1    2004-03-10 19:00:00  10/03/2004  19.00.00     2.0       1292.0     112.0
# 2    2004-03-10 20:00:00  10/03/2004  20.00.00     2.2       1402.0      88.0
# 3    2004-03-10 21:00:00  10/03/2004  21.00.00     2.2       1376.0      80.0
# 4    2004-03-10 22:00:00  10/03/2004  22.00.00     1.6       1272.0      51.0
# ...                  ...         ...       ...     ...          ...       ...
# 9352 2005-04-04 10:00:00  04/04/2005  10.00.00     3.1       1314.0       NaN
# 9353 2005-04-04 11:00:00  04/04/2005  11.00.00     2.4       1163.0       NaN
# 9354 2005-04-04 12:00:00  04/04/2005  12.00.00     2.4       1142.0       NaN
# 9355 2005-04-04 13:00:00  04/04/2005  13.00.00     2.1       1003.0       NaN
# 9356 2005-04-04 14:00:00  04/04/2005  14.00.00     2.2       1071.0       NaN
#
# ...

# %%
column_dict = []
dfs = []
for i, column in enumerate(df_air.columns[3:]):
    column_dict.append([column, i])
    df_temp = df_air[['ds', column]].copy()
    df_temp = df_temp.rename(columns={column: 'y'})
    df_temp['unique_id'] = i
    dfs.append(df_temp)
    # display(df_temp)
df = pd.concat(dfs)
df = df.reset_index(drop=True)
df
# Out:
#                         ds       y  unique_id
# 0      2004-03-10 18:00:00  2.6000          0
# 1      2004-03-10 19:00:00  2.0000          0
# 2      2004-03-10 20:00:00  2.2000          0
# 3      2004-03-10 21:00:00  2.2000          0
# 4      2004-03-10 22:00:00  1.6000          0
# ...                    ...     ...        ...
# 121636 2005-04-04 10:00:00  0.7568         12
# 121637 2005-04-04 11:00:00  0.7119         12
# 121638 2005-04-04 12:00:00  0.6406         12
# 121639 2005-04-04 13:00:00  0.5139         12
# 121640 2005-04-04 14:00:00  0.5028         12
#
# [121641 rows x 3 columns]

# %%
# df.to_csv('data/air+quality/y_air_quality.csv')
# pd.DataFrame(column_dict, columns = ['unique_id', 'mapped_id']).to_csv('data/air+quality/id_mapping.csv')

# %%
def plot_df(df, id, timestamp, graph_before, steps_ahead, plt_tmp=plt):
    true_y = df.loc[(df["unique_id"]==id) & (df["ds"]>=timestamp-pd.Timedelta(graph_before, unit='h')) & (df["ds"]<timestamp+pd.Timedelta(max(steps_ahead,24), unit='h')), "y"].to_numpy().flatten()
    plt_tmp.plot(df.loc[(df["unique_id"]==id) & (df["ds"]>=timestamp-pd.Timedelta(graph_before, unit='h')) & (df["ds"]<timestamp+pd.Timedelta(max(steps_ahead,24), unit='h')), "ds"].to_numpy().flatten(), true_y, label=f"True", linewidth=1, color='r')

plt.figure(figsize=(24,6))
id = 3
timestamp = pd.Timestamp("2004-08-12 00:00:00")
graph_before = 24*7*3
steps_ahead = 24
plot_df(df, id, timestamp, graph_before, steps_ahead)
plt.ylabel(column_dict[id][0])
plt.xlabel("Date")
plt.show()
